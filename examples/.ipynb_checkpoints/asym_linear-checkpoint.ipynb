# %% [markdown]
# # Asymmetric Total Variation Example

# %%
import sys, os
os.getcwd()
# Out:
# '/Users/ashchepetn001/Documents/MyWorkspace/non-linear-normalization/examples'

# %%
PATH = '../'
if PATH not in sys.path:
    sys.path.append(os.path.abspath(PATH))

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

mpl.rcParams["figure.figsize"] = [30, 10]
mpl.rcParams["axes.titlesize"] = 20
mpl.rcParams["axes.labelsize"] = 20
mpl.rcParams["legend.fontsize"] = 20
mpl.rcParams["xtick.labelsize"] = 20
mpl.rcParams["ytick.labelsize"] = 20

# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from nlnorm.asymmetric.lasso import AsymmetricLasso
from nlnorm.asymmetric.ridge import AsymmetricRidge

# %% [markdown]
# Signal parameters

# %%
SIGNAL_LENGTH = 1000
NUM_PIECES = 5
NUM_FREQS = 4

# %% [markdown]
# Generate signal

# %%
t = np.arange(SIGNAL_LENGTH)
signal = np.zeros(shape=(SIGNAL_LENGTH, ))

piece_len = SIGNAL_LENGTH / (NUM_PIECES)

for p in range(NUM_PIECES):
    p_start = int(p * piece_len)
    p_end = int((p + 1) * piece_len)
    
    a = np.random.normal()
    
    
    if p > 0:
        b = signal[p_start - 1]
    else:
        b = 0
        
    signal[p_start:p_end] = a * np.arange(p_end - p_start) + b
    
  
s_std = np.std(signal)

freqs = np.random.uniform(SIGNAL_LENGTH / 100, SIGNAL_LENGTH / 5, NUM_FREQS)

for f in freqs:
    signal += s_std * np.sin(2 * np.pi * t / f)
         
signal += np.random.normal(0, np.std(signal) / 4, SIGNAL_LENGTH)

# %%
signal = (signal - np.mean(signal)) / np.std(signal)

# %%
plt.plot(signal)

# %%
asym_ridge = AsymmetricRidge(alpha = 0.99,
                 alpha_ridge=1,
                 tol = 1e-6,
                 max_iter= 10,
                 outliers=0.001,
                ridge_params={'tol': 1e-6})

# %% [markdown]
# Apply total variation to generate linear slopes

# %%
asym_lasso = AsymmetricLasso(alpha=0.99,
                 alpha_lasso=0.1,
                 tol=1e-9,
                 max_iter=10,
                 outliers= None,
                 diff_order=2,
                lasso_params={'max_iter': 1000, 'warm_start': True, 'selection': 'random', 'precompute': True})

# %%
# print(asym_lasso.coef_)

# %%
est = asym_lasso.predict(signal)
plt.plot(signal)
plt.plot(est)
# Out:
# /Users/ashchepetn001/Library/Caches/pypoetry/virtualenvs/cg-reasoner-service-szftukA7-py3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11465268713294563, tolerance: 0.038988902622989305
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
lam = np.std(signal_1) * 1e+2

res_low, costs_low = asym_tvd_linear(signal_1,
                                    p_asym=0.01,
                                    n_iter=5,
                                    n_tvd_iter=10,
                                    lam=lam,
                                    outliers=None)
res_up, costs_up = asym_tvd_linear(signal_1,
                                    p_asym=1 - 0.01,
                                    n_iter=5,
                                    n_tvd_iter=10,
                                    lam=lam,
                                    outliers=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [130], in <module>
# ----> 1 lam = np.std(signal_1) * 1e+2
#       3 res_low, costs_low = asym_tvd_linear(signal_1,
#       4                                     p_asym=0.01,
#       5                                     n_iter=5,
#       6                                     n_tvd_iter=10,
#       7                                     lam=lam,
#       8                                     outliers=None)
#       9 res_up, costs_up = asym_tvd_linear(signal_1,
#      10                                     p_asym=1 - 0.01,
#      11                                     n_iter=5,
#      12                                     n_tvd_iter=10,
#      13                                     lam=lam,
#      14                                     outliers=None)
#
# NameError: name 'signal_1' is not defined

# %%
fig, axes = plt.subplots(3, 1, figsize=(30, 30))

axes[0].set_title('Signal and linear slopes')
axes[0].plot(signal_1, label='Signal')
axes[0].plot(res_low, label='Linear lower slope')
axes[0].plot(res_up, label='Linear upper slope')
axes[0].legend()

axes[1].plot(np.diff(res_up, 2))
axes[1].set_title('Upper slope second difference')
axes[2].plot(np.diff(res_low, 2))
axes[2].set_title('Upper slope second difference')
# Out:
# Text(0.5, 1.0, 'Upper slope second difference')

# %% [markdown]
# Plot costs

# %%
for cost in costs:
    ax = plt.plot(cost)
plt.yscale('log')
